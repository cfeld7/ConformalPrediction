# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor

# %matplotlib inline

# %%
df = pd.read_csv("AmesHousingWithAddress.csv")

df = df[["SalePrice", "Lot Area", "Gr Liv Area", "Total Bsmt SF", "Open Porch SF", "Wood Deck SF", "Garage Area", 
        "Bedroom AbvGr", "Full Bath", "Bsmt Full Bath", "Kitchen AbvGr", "Fireplaces", "Neighborhood", 
        "Year Built", "Year Remod/Add"]]

le = LabelEncoder()
df["Neighborhood"] = le.fit_transform(df["Neighborhood"])

df["Bsmt Full Bath"] = df["Bsmt Full Bath"].fillna(0)

df.head()
# Out:
#    SalePrice  Lot Area  Gr Liv Area  Total Bsmt SF  Open Porch SF  \
# 0     215000     31770         1656           1080             62
# 1     105000     11622          896            882              0
# 2     172000     14267         1329           1329             36
# 3     244000     11160         2110           2110              0
# 4     189900     13830         1629            928             34
#
#    Wood Deck SF  Garage Area  Bedroom AbvGr  Full Bath  Bsmt Full Bath  \
# 0           210          528              3          1             1.0
# 1           140          730              2          1             0.0
# 2           393          312              3          1             0.0
# 3             0          522              3          2             1.0
# 4           212          482              3          2             0.0
#
#    Kitchen AbvGr  Fireplaces  Neighborhood  Year Built  Year Remod/Add
# 0              1           2            13        1960            1960
# 1              1           0            13        1961            1961
# 2              1           0            13        1958            1958
# 3              1           2            13        1968            1968
# 4              1           1             8        1997            1998

# %%
def conformal_prediction(df, regressor, gamma, confidence):
    
    data_0 = df.sample(frac = 0.2, axis = "index")

    data_1 = df[~df.isin(data_0)].dropna(how = "any").sample(frac = 0.25, axis = "index")

    data_2 = df[~df.isin(data_0)].dropna(how = "any")
    data_2 = data_2[~data_2.isin(data_1)].dropna(how = "any").sample(frac = 0.333, axis = "index")

    data_3 = df[~df.isin(data_0)].dropna(how = "any")
    data_3 = data_3[~data_3.isin(data_1)].dropna(how = "any")
    data_3 = data_3[~data_3.isin(data_2)].dropna(how = "any").sample(frac = 0.5, axis = "index")

    data_4 = df[~df.isin(data_0)].dropna(how = "any")
    data_4 = data_4[~data_4.isin(data_1)].dropna(how = "any")
    data_4 = data_4[~data_4.isin(data_2)].dropna(how = "any")
    data_4 = data_4[~data_4.isin(data_3)].dropna(how = "any")

    cross_val_list = [data_0, data_1, data_2, data_3, data_4]

    for i in range(len(cross_val_list)):
        
        train_data = cross_val_list[0:3]
        train_data = pd.concat([train_data[0], train_data[1], train_data[2]])
        cal_data = cross_val_list[3]
        test_data = cross_val_list[4]       
        
        X_train = train_data[["Lot Area", "Gr Liv Area", "Total Bsmt SF", "Open Porch SF", "Wood Deck SF", "Garage Area", 
                            "Bedroom AbvGr", "Full Bath", "Bsmt Full Bath", "Kitchen AbvGr", "Fireplaces", "Neighborhood", 
                            "Year Built", "Year Remod/Add"]]
        y_train = train_data["SalePrice"]

        X_cal = cal_data[["Lot Area", "Gr Liv Area", "Total Bsmt SF", "Open Porch SF", "Wood Deck SF", "Garage Area", 
                            "Bedroom AbvGr", "Full Bath", "Bsmt Full Bath", "Kitchen AbvGr", "Fireplaces", "Neighborhood", 
                            "Year Built", "Year Remod/Add"]]
        y_cal = cal_data["SalePrice"]

        X_test = test_data[["Lot Area", "Gr Liv Area", "Total Bsmt SF", "Open Porch SF", "Wood Deck SF", "Garage Area", 
                            "Bedroom AbvGr", "Full Bath", "Bsmt Full Bath", "Kitchen AbvGr", "Fireplaces", "Neighborhood", 
                            "Year Built", "Year Remod/Add"]]
        y_test = test_data["SalePrice"]

        reg = regressor
        
        reg2 = RandomForestRegressor()

        reg.fit(X_train, y_train)
        train_pred = reg.predict(X_train)
        y_cal_pred = reg.predict(X_cal)
        y_test_pred = reg.predict(X_test)
        
        train_resid = abs((y_train - train_pred))
        train_mu = np.log(abs(y_train - train_pred + 0.05))
        #print(train_mu.to_string())
        reg2.fit(X_train, train_mu)
        
        mu_cal_pred = reg2.predict(X_cal)
        mu_test_pred = reg2.predict(X_test)

        # Nonconformity Measure
        ncm = abs((y_cal - y_cal_pred) / (gamma + np.exp(mu_cal_pred)))
        ncm = list(ncm)
        
        q = np.quantile(ncm, confidence)
        
        lower = y_test_pred - (q * (gamma + np.exp(mu_test_pred)))
        upper = y_test_pred + (q * (gamma + np.exp(mu_test_pred)))
        global pred_intervals
        pred_intervals = list(zip(lower, upper))

        covered_count = 0
        not_covered_count = 0

        y_test.reset_index(drop = True, inplace = True)

        for i in range(len(y_test)):
            if (y_test[i] >= pred_intervals[i][0]) & (y_test[i] <= pred_intervals[i][1]):
                covered_count += 1
            else:
                not_covered_count += 1

        global coverage
        coverage = covered_count / (covered_count + not_covered_count)

        global int_size
        int_size = pred_intervals[0][1] - pred_intervals[0][0]

        cross_val_list.append(cross_val_list.pop(0))

# %%
regressors = [LinearRegression(), GradientBoostingRegressor(), RandomForestRegressor()]

confidences = [0.9, 0.95, 0.99]
gammas = [0, 2500, 5000, 10000, 20000, 40000]

# %%
n_trials = 100

for reg in regressors:
    for conf in confidences:
        for gamma in gammas:
            total_cvg = 0
            int_size_list = []
            for trial in range(n_trials):
                conformal_prediction(df, reg, gamma, conf)
                total_cvg += coverage
                int_size_list.append(int_size)
                #total_int_size += int_size
            print("Model: " + str(reg))
            print("Confidence: " + str(conf*100) + "%")
            print("Gamma Value: " + str(gamma))
            print("Average Coverage: " + str(total_cvg / n_trials))
            print("Median Interval Width: " + str(np.median(int_size_list)))
            print("--------------------------------------------------------------------")
            #print("Average Interval Width: " + str(total_int_size / n_trials))
# Out:
# Model: LinearRegression()
# Confidence: 90.0%
# Gamma Value: 0
# Average Coverage: 0.900694143167028
# Median Interval Width: 78742.55642767373
# --------------------------------------------------------------------
# Model: LinearRegression()
# Confidence: 90.0%
# Gamma Value: 2500
# Average Coverage: 0.8989804772234276
# Median Interval Width: 67437.69467277353
# --------------------------------------------------------------------
# Model: LinearRegression()
# Confidence: 90.0%
# Gamma Value: 5000
# Average Coverage: 0.8972234273318871
# Median Interval Width: 69905.97234475761
# --------------------------------------------------------------------
# Model: LinearRegression()
# Confidence: 90.0%
# Gamma Value: 10000
# Average Coverage: 0.8977440347071587
# Median Interval Width: 69948.75583363482
# --------------------------------------------------------------------
# Model: LinearRegression()
# Confidence: 90.0%
# Gamma Value: 20000
# Average Coverage: 0.8990455531453364
# Median Interval Width: 73709.75768376933
# --------------------------------------------------------------------
# Model: LinearRegression()
# Confidence: 90.0%
# Gamma Value: 40000
# Average Coverage: 0.896182212581345
# Median Interval Width: 77034.39522895982
# --------------------------------------------------------------------
# Model: LinearRegression()
# Confidence: 95.0%
# Gamma Value: 0
# Average Coverage: 0.9479826464208239
# Median Interval Width: 94724.46013709684
# --------------------------------------------------------------------
# Model: LinearRegression()
# Confidence: 95.0%
# Gamma Value: 2500
# Average Coverage: 0.947722342733188
# Median Interval Width: 78604.22601854583
# --------------------------------------------------------------------
# Model: LinearRegression()
# Confidence: 95.0%
# Gamma Value: 5000
# Average Coverage: 0.9511930585683293
# Median Interval Width: 87876.70025078073
# --------------------------------------------------------------------
# Model: LinearRegression()
# Confidence: 95.0%
# Gamma Value: 10000
# Average Coverage: 0.9443817787418655
# Median Interval Width: 89742.47168488248
# --------------------------------------------------------------------
# Model: LinearRegression()
# Confidence: 95.0%
# Gamma Value: 20000
# Average Coverage: 0.9505856832971794
# Median Interval Width: 93611.77192484133
# --------------------------------------------------------------------
# Model: LinearRegression()
# Confidence: 95.0%
# Gamma Value: 40000
# Average Coverage: 0.9490021691973964
# Median Interval Width: 95629.32010368639
# --------------------------------------------------------------------
# Model: LinearRegression()
# Confidence: 99.0%
# Gamma Value: 0
# Average Coverage: 0.9876572668112792
# Median Interval Width: 136121.69382474013
# --------------------------------------------------------------------
# Model: LinearRegression()
# Confidence: 99.0%
# Gamma Value: 2500
# Average Coverage: 0.9888069414316696
# Median Interval Width: 138160.2816040069
# --------------------------------------------------------------------
# Model: LinearRegression()
# Confidence: 99.0%
# Gamma Value: 5000
# Average Coverage: 0.9876138828633395
# Median Interval Width: 129842.431912075
# --------------------------------------------------------------------
# Model: LinearRegression()
# Confidence: 99.0%
# Gamma Value: 10000
# Average Coverage: 0.9888503253796082
# Median Interval Width: 131495.3227993296
# --------------------------------------------------------------------
# Model: LinearRegression()
# Confidence: 99.0%
# Gamma Value: 20000
# Average Coverage: 0.9879609544468535
# Median Interval Width: 139480.138665842
# --------------------------------------------------------------------
# Model: LinearRegression()
# Confidence: 99.0%
# Gamma Value: 40000
# Average Coverage: 0.9874403470715829
# Median Interval Width: 157345.2880174928
# --------------------------------------------------------------------
# Model: GradientBoostingRegressor()
# Confidence: 90.0%
# Gamma Value: 0
# Average Coverage: 0.9013015184381777
# Median Interval Width: 71133.25669906962
# --------------------------------------------------------------------
# Model: GradientBoostingRegressor()
# Confidence: 90.0%
# Gamma Value: 2500
# Average Coverage: 0.8962039045553146
# Median Interval Width: 66977.68414870775
# --------------------------------------------------------------------
# Model: GradientBoostingRegressor()
# Confidence: 90.0%
# Gamma Value: 5000
# Average Coverage: 0.8974620390455531
# Median Interval Width: 65345.31067813229
# --------------------------------------------------------------------
# Model: GradientBoostingRegressor()
# Confidence: 90.0%
# Gamma Value: 10000
# Average Coverage: 0.8954663774403471
# Median Interval Width: 62395.25404759269
# --------------------------------------------------------------------
# Model: GradientBoostingRegressor()
# Confidence: 90.0%
# Gamma Value: 20000
# Average Coverage: 0.8999132321041218
# Median Interval Width: 65575.39739320359
# --------------------------------------------------------------------
# Model: GradientBoostingRegressor()
# Confidence: 90.0%
# Gamma Value: 40000
# Average Coverage: 0.9000433839479398
# Median Interval Width: 66336.19899710728
# --------------------------------------------------------------------
# Model: GradientBoostingRegressor()
# Confidence: 95.0%
# Gamma Value: 0
# Average Coverage: 0.9485900216919735
# Median Interval Width: 94226.325616387
# --------------------------------------------------------------------
# Model: GradientBoostingRegressor()
# Confidence: 95.0%
# Gamma Value: 2500
# Average Coverage: 0.9487418655097613
# Median Interval Width: 85529.64240798878
# --------------------------------------------------------------------
# Model: GradientBoostingRegressor()
# Confidence: 95.0%
# Gamma Value: 5000
# Average Coverage: 0.9474403470715831
# Median Interval Width: 84383.96003696867
# --------------------------------------------------------------------
# Model: GradientBoostingRegressor()
# Confidence: 95.0%
# Gamma Value: 10000
# Average Coverage: 0.9476572668112792
# Median Interval Width: 82946.58265014709
# --------------------------------------------------------------------
# Model: GradientBoostingRegressor()
# Confidence: 95.0%
# Gamma Value: 20000
# Average Coverage: 0.9474186550976132
# Median Interval Width: 86308.60246940951
# --------------------------------------------------------------------
# Model: GradientBoostingRegressor()
# Confidence: 95.0%
# Gamma Value: 40000
# Average Coverage: 0.9481778741865503
# Median Interval Width: 87287.03214569039
# --------------------------------------------------------------------
# Model: GradientBoostingRegressor()
# Confidence: 99.0%
# Gamma Value: 0
# Average Coverage: 0.9872885032537951
# Median Interval Width: 154836.02772657236
# --------------------------------------------------------------------
# Model: GradientBoostingRegressor()
# Confidence: 99.0%
# Gamma Value: 2500
# Average Coverage: 0.9879609544468535
# Median Interval Width: 144934.72798846356
# --------------------------------------------------------------------
# Model: GradientBoostingRegressor()
# Confidence: 99.0%
# Gamma Value: 5000
# Average Coverage: 0.9882646420824286
# Median Interval Width: 144181.6707095883
# --------------------------------------------------------------------
# Model: GradientBoostingRegressor()
# Confidence: 99.0%
# Gamma Value: 10000
# Average Coverage: 0.9878741865509751
# Median Interval Width: 135227.54119787907
# --------------------------------------------------------------------
# Model: GradientBoostingRegressor()
# Confidence: 99.0%
# Gamma Value: 20000
# Average Coverage: 0.987245119305856
# Median Interval Width: 140770.91791361067
# --------------------------------------------------------------------
# Model: GradientBoostingRegressor()
# Confidence: 99.0%
# Gamma Value: 40000
# Average Coverage: 0.9891540130151836
# Median Interval Width: 145968.25397234794
# --------------------------------------------------------------------
# Model: RandomForestRegressor()
# Confidence: 90.0%
# Gamma Value: 0
# Average Coverage: 0.896420824295011
# Median Interval Width: 65784.71706654383
# --------------------------------------------------------------------
# Model: RandomForestRegressor()
# Confidence: 90.0%
# Gamma Value: 2500
# Average Coverage: 0.8991540130151843
# Median Interval Width: 60132.99322440772
# --------------------------------------------------------------------
# Model: RandomForestRegressor()
# Confidence: 90.0%
# Gamma Value: 5000
# Average Coverage: 0.9006290672451192
# Median Interval Width: 66284.34183665465
# --------------------------------------------------------------------
# Model: RandomForestRegressor()
# Confidence: 90.0%
# Gamma Value: 10000
# Average Coverage: 0.8993926247288502
# Median Interval Width: 64741.68220261436
# --------------------------------------------------------------------
# Model: RandomForestRegressor()
# Confidence: 90.0%
# Gamma Value: 20000
# Average Coverage: 0.8987201735357918
# Median Interval Width: 67635.50706454308
# --------------------------------------------------------------------
# Model: RandomForestRegressor()
# Confidence: 90.0%
# Gamma Value: 40000
# Average Coverage: 0.9012147505422992
# Median Interval Width: 71069.70069778946
# --------------------------------------------------------------------
# Model: RandomForestRegressor()
# Confidence: 95.0%
# Gamma Value: 0
# Average Coverage: 0.9447071583514095
# Median Interval Width: 95632.05913682313
# --------------------------------------------------------------------
# Model: RandomForestRegressor()
# Confidence: 95.0%
# Gamma Value: 2500
# Average Coverage: 0.9472234273318864
# Median Interval Width: 75607.16148602325
# --------------------------------------------------------------------
# Model: RandomForestRegressor()
# Confidence: 95.0%
# Gamma Value: 5000
# Average Coverage: 0.9484815618221254
# Median Interval Width: 80525.86101881918
# --------------------------------------------------------------------
# Model: RandomForestRegressor()
# Confidence: 95.0%
# Gamma Value: 10000
# Average Coverage: 0.9481344902386114
# Median Interval Width: 84896.41827903726
# --------------------------------------------------------------------
# Model: RandomForestRegressor()
# Confidence: 95.0%
# Gamma Value: 20000
# Average Coverage: 0.949154013015184
# Median Interval Width: 89153.50177338274
# --------------------------------------------------------------------
# Model: RandomForestRegressor()
# Confidence: 95.0%
# Gamma Value: 40000
# Average Coverage: 0.9511062906724507
# Median Interval Width: 92886.03054809652
# --------------------------------------------------------------------
# Model: RandomForestRegressor()
# Confidence: 99.0%
# Gamma Value: 0
# Average Coverage: 0.9878091106290661
# Median Interval Width: 142424.20315111824
# --------------------------------------------------------------------
# Model: RandomForestRegressor()
# Confidence: 99.0%
# Gamma Value: 2500
# Average Coverage: 0.9873101952277655
# Median Interval Width: 120965.48659334796
# --------------------------------------------------------------------
# Model: RandomForestRegressor()
# Confidence: 99.0%
# Gamma Value: 5000
# Average Coverage: 0.9877006507592188
# Median Interval Width: 116486.65628379805
# --------------------------------------------------------------------
# Model: RandomForestRegressor()
# Confidence: 99.0%
# Gamma Value: 10000
# Average Coverage: 0.9880260303687627
# Median Interval Width: 128840.64746199118
# --------------------------------------------------------------------
# Model: RandomForestRegressor()
# Confidence: 99.0%
# Gamma Value: 20000
# Average Coverage: 0.9872017353579169
# Median Interval Width: 139314.27063639776
# --------------------------------------------------------------------
# Model: RandomForestRegressor()
# Confidence: 99.0%
# Gamma Value: 40000
# Average Coverage: 0.9893492407809099
# Median Interval Width: 148023.7005196553
# --------------------------------------------------------------------
